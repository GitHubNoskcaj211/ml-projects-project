# %%
import sys
import os
sys.path.append(os.path.join(os.path.abspath(''), '../'))

from evaluation.evaluation_harness import SAVED_EVALUATION_PATH
import os
import pandas as pd

# %%
def parse_metrics_file(file_path):
    metrics = {}
    with open(file_path, 'r') as file:
        for line in file:
            key, value = line.strip().split(': ')
            metrics[key] = float(value)
    return metrics

subfolders = [f.path for f in os.scandir(SAVED_EVALUATION_PATH) if f.is_dir()]
data = []
for subfolder in subfolders:
    metrics_file_path = os.path.join(subfolder, 'metrics.txt')
    
    if os.path.exists(metrics_file_path):
        metrics_data = parse_metrics_file(metrics_file_path)
        data.append({'evaluation_name': subfolder.split('/')[-1], **metrics_data})

results = pd.DataFrame(data)

# %%
def display_ranked_column(column_name):
    display(results.sort_values(by=column_name, ascending=False)[['evaluation_name', column_name]])

# %%
display_ranked_column('user_rank_auc_roc')
# Out:
#                                       evaluation_name  user_rank_auc_roc
# 52             test_common_neighbors_constant_scoring           0.668630
# 85           test_common_neighbors_percentile_scoring           0.665718
# 86    evaluation_cold_fine_tune_test_popularity_model           0.660295
# 57             test_popularity_model_constant_scoring           0.660133
# 94                              test_popularity_model           0.660133
# ..                                                ...                ...
# 32  TEMP_evaluation_cold_fine_tune_test_mlp_200ep_...           0.475128
# 49  TEMP_evaluation_cold_fine_tune_test_ncf_200ep_...           0.465037
# 73  TEMP_evaluation_cold_fine_tune_test_mlp_200ep_...           0.458632
# 90  TEMP_evaluation_cold_fine_tune_test_mlp_200ep_...           0.453394
# 37                          evaluation_test_graphsage           0.374123
#
# [103 rows x 2 columns]

# %%
display_ranked_column('auc_roc')
# Out:
#                                       evaluation_name   auc_roc
# 13             test_common_neighbors_constant_scoring  0.879927
# 25           test_common_neighbors_percentile_scoring  0.878156
# 14    evaluation_warm_fine_tune_test_common_neighbors  0.861633
# 0                               test_common_neighbors  0.861342
# 5     evaluation_cold_fine_tune_test_common_neighbors  0.814534
# 23   evaluation_test_gcf_embed_all_except_tags_genres  0.793709
# 10  evaluation_test_gcf_low_weight_decay_increased_lr  0.773812
# 12   evaluation_test_mlp_embed_all_except_tags_genres  0.741777
# 1    evaluation_test_ncf_embed_all_except_tags_genres  0.732807
# 7    evaluation_test_cf_low_weight_decay_increased_lr  0.732643
# 16  evaluation_test_ncf_low_weight_decay_increased_lr  0.731144
# 15  evaluation_test_mlp_low_weight_decay_increased_lr  0.729132
# 8     evaluation_test_cf_embed_all_except_tags_genres  0.725672
# 31                 evaluation_warm_fine_tune_test_mlp  0.701312
# ...

# %%
display_ranked_column('mean_positional_error')
# Out:
#                                       evaluation_name  mean_positional_error
# 18                  evaluation_cold_fine_tune_test_cf              21.937443
# 2         evaluation_cold_fine_tune_test_random_model              21.705717
# 22                 evaluation_cold_fine_tune_test_mlp              21.598369
# 19                 evaluation_cold_fine_tune_test_gcf              21.379207
# 30                 evaluation_cold_fine_tune_test_ncf              21.178240
# 24        evaluation_warm_fine_tune_test_random_model              20.938622
# 6                                   test_random_model              20.881921
# 20                  evaluation_warm_fine_tune_test_cf              20.860944
# 28                 evaluation_warm_fine_tune_test_gcf              20.493645
# 31                 evaluation_warm_fine_tune_test_mlp              20.172420
# 17             test_popularity_model_constant_scoring              20.082545
# ...

# %%
display(results)
# Out:
#                                       evaluation_name  mean_positional_error  \
# 0                               test_common_neighbors              17.231736
# 1    evaluation_test_ncf_embed_all_except_tags_genres              12.809617
# 2         evaluation_cold_fine_tune_test_random_model              21.705717
# 3   TEMP_evaluation_warm_fine_tune_test_cf_no_fine...              11.170494
# 4                  test_random_model_constant_scoring              20.078981
# 5     evaluation_cold_fine_tune_test_common_neighbors              17.302018
# 6                                   test_random_model              20.881921
# 7    evaluation_test_cf_low_weight_decay_increased_lr              13.750220
# 8     evaluation_test_cf_embed_all_except_tags_genres              14.131554
# 9              TEMP_evaluation_warm_fine_tune_test_cf              18.641218
# 10  evaluation_test_gcf_low_weight_decay_increased_lr              14.723952
# ...

# %%
evaluation_names = {'test_common_neighbors': 'evaluation_train_common_neighbors', 'evaluation_warm_fine_tune_test_common_neighbors': 'evaluation_warm_fine_tune_common_neighbors', 'evaluation_cold_fine_tune_test_common_neighbors': 'evaluation_cold_fine_tune_common_neighbors'}
df = results.loc[results['evaluation_name'].isin(evaluation_names.keys()), ['evaluation_name', 'mean_positional_error', 'auc_roc', 'user_rank_auc_roc']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='auc_roc', ascending=False))
# Out:
#                                evaluation_name  mean_positional_error  \
# 14  evaluation_warm_fine_tune_common_neighbors              17.147502
# 0            evaluation_train_common_neighbors              17.231736
# 5   evaluation_cold_fine_tune_common_neighbors              17.302018
#
#      auc_roc  user_rank_auc_roc
# 14  0.861633           0.650856
# 0   0.861342           0.651126
# 5   0.814534           0.652850

# %%
evaluation_names = {'test_random_model': 'random_model', 'test_popularity_model': 'popularity_model', 'test_common_neighbors': 'common_neighbors', 'evaluation_test_cf_low_weight_decay_increased_lr': 'collborative_filter', 'evaluation_test_gcf_low_weight_decay_increased_lr': 'non_linear_collaborative_filter', 'evaluation_test_mlp_low_weight_decay_increased_lr': 'multilayer_perceptron', 'evaluation_test_ncf_low_weight_decay_increased_lr': 'neural_collaborative_filter'}
df = results.loc[results['evaluation_name'].isin(evaluation_names.keys()), ['evaluation_name', 'mean_positional_error', 'auc_roc', 'user_rank_auc_roc']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='auc_roc', ascending=False))
# Out:
#                     evaluation_name  mean_positional_error   auc_roc  \
# 0                  common_neighbors              17.231736  0.861342
# 10  non_linear_collaborative_filter              14.723952  0.773812
# 7               collborative_filter              13.750220  0.732643
# 16      neural_collaborative_filter              12.825469  0.731144
# 15            multilayer_perceptron              13.033273  0.729132
# 29                 popularity_model              18.282347  0.551558
# 6                      random_model              20.881921  0.438924
#
#     user_rank_auc_roc
# 0            0.651126
# 10           0.616624
# 7            0.594917
# 16           0.603030
# 15           0.605583
# 29           0.660133
# 6            0.500380

# %%
evaluation_names = {'evaluation_test_cf_low_weight_decay_increased_lr': 'collborative_filter', 'evaluation_test_gcf_low_weight_decay_increased_lr': 'non_linear_collaborative_filter', 'evaluation_test_mlp_low_weight_decay_increased_lr': 'multilayer_perceptron', 'evaluation_test_ncf_low_weight_decay_increased_lr': 'neural_collaborative_filter', 'evaluation_test_cf_embed_all_except_tags_genres': 'collborative_filter_with_game_embeddings', 'evaluation_test_gcf_embed_all_except_tags_genres': 'non_linear_collaborative_filter_with_game_embeddings', 'evaluation_test_mlp_embed_all_except_tags_genres': 'multilayer_perceptron_with_game_embeddings', 'evaluation_test_ncf_embed_all_except_tags_genres': 'neural_collaborative_filter_with_game_embeddings'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'mean_positional_error', 'auc_roc', 'user_rank_auc_roc']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='auc_roc', ascending=False))
# Out:
#                                       evaluation_name  mean_positional_error  \
# 23  non_linear_collaborative_filter_with_game_embe...              14.341733
# 10                    non_linear_collaborative_filter              14.723952
# 12         multilayer_perceptron_with_game_embeddings              12.536034
# 1    neural_collaborative_filter_with_game_embeddings              12.809617
# 7                                 collborative_filter              13.750220
# 16                        neural_collaborative_filter              12.825469
# 15                              multilayer_perceptron              13.033273
# 8            collborative_filter_with_game_embeddings              14.131554
#
#      auc_roc  user_rank_auc_roc
# 23  0.793709           0.641797
# 10  0.773812           0.616624
# 12  0.741777           0.598630
# 1   0.732807           0.615793
# 7   0.732643           0.594917
# 16  0.731144           0.603030
# 15  0.729132           0.605583
# ...

# %%
evaluation_names = {'test_random_model': 'random_model', 'test_popularity_model': 'popularity_model', 'test_common_neighbors': 'common_neighbors', 'evaluation_test_cf_low_weight_decay_increased_lr_best_model_bugfix': 'cf', 'evaluation_test_gcf_low_weight_decay_increased_lr_best_model_bugfix': 'non_linear_cf', 'evaluation_test_mlp_low_weight_decay_increased_lr_best_model_bugfix': 'mlp', 'evaluation_test_ncf_low_weight_decay_increased_lr_best_model_bugfix': 'ncf', 'evaluation_test_cf_embed_all_except_tags_genres_best_model_bugfix_clip_embeddings': 'cf_with_game_embeddings', 'evaluation_test_gcf_embed_all_except_tags_genres_best_model_bugfix_clip_embeddings': 'non_linear_cf_with_game_embeddings', 'evaluation_test_mlp_embed_all_except_tags_genres_best_model_bugfix_clip_embeddings': 'mlp_with_game_embeddings', 'evaluation_test_ncf_embed_all_except_tags_genres_best_model_bugfix_clip_embeddings': 'ncf_with_game_embeddings'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'user_rank_auc_roc', 'auc_roc', 'mean_positional_error']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='user_rank_auc_roc', ascending=False))
# Out:
#                         evaluation_name  user_rank_auc_roc   auc_roc  \
# 94                     popularity_model           0.660133  0.551558
# 1                      common_neighbors           0.651126  0.861342
# 61                        non_linear_cf           0.616624  0.773812
# 92              cf_with_game_embeddings           0.611802  0.712199
# 30             mlp_with_game_embeddings           0.608055  0.753442
# 101                                 mlp           0.605583  0.729132
# 12                                  ncf           0.603030  0.731144
# 45             ncf_with_game_embeddings           0.600803  0.713629
# 53                                   cf           0.594917  0.732643
# 79   non_linear_cf_with_game_embeddings           0.594575  0.842221
# 11                         random_model           0.500380  0.438924
#
#      mean_positional_error
# 94               18.282347
# 1                17.231736
# 61               14.723952
# ...

# %%
evaluation_names = {'evaluation_warm_fine_tune_test_random_model': 'random_model', 'evaluation_warm_fine_tune_test_popularity_model': 'popularity_model', 'evaluation_warm_fine_tune_test_common_neighbors': 'common_neighbors', 'evaluation_warm_fine_tune_test_cf': 'cf', 'evaluation_warm_fine_tune_test_gcf': 'non_linear_cf', 'evaluation_warm_fine_tune_test_mlp': 'mlp', 'evaluation_warm_fine_tune_test_ncf': 'ncf', 'evaluation_warm_fine_tune_test_cf_embed_all_except_tags_genres': 'cf_with_game_embeddings', 'evaluation_warm_fine_tune_test_gcf_embed_all_except_tags_genres': 'non_linear_cf_with_game_embeddings', 'evaluation_warm_fine_tune_test_mlp_embed_all_except_tags_genres': 'mlp_with_game_embeddings', 'evaluation_warm_fine_tune_test_ncf_embed_all_except_tags_genres': 'ncf_with_game_embeddings'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'user_rank_auc_roc', 'auc_roc', 'mean_positional_error']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='user_rank_auc_roc', ascending=False))
# Out:
#                         evaluation_name  user_rank_auc_roc   auc_roc  \
# 48                     popularity_model           0.659982  0.551399
# 56                     common_neighbors           0.650856  0.861633
# 72                                  ncf           0.630138  0.693617
# 93                        non_linear_cf           0.630014  0.520712
# 6              mlp_with_game_embeddings           0.621237  0.759961
# 64   non_linear_cf_with_game_embeddings           0.613032  0.529598
# 102                                 mlp           0.611337  0.711663
# 42             ncf_with_game_embeddings           0.609272  0.712614
# 70                                   cf           0.605995  0.638762
# 91              cf_with_game_embeddings           0.595932  0.696092
# 81                         random_model           0.502332  0.440129
#
#      mean_positional_error
# 48               18.267066
# 56               17.147502
# 72               13.984669
# ...

# %%
evaluation_names = {'evaluation_cold_fine_tune_test_random_model': 'random_model', 'evaluation_cold_fine_tune_test_popularity_model': 'popularity_model', 'evaluation_cold_fine_tune_test_common_neighbors': 'common_neighbors', 'evaluation_cold_fine_tune_test_cf': 'cf', 'evaluation_cold_fine_tune_test_gcf': 'non_linear_cf', 'evaluation_cold_fine_tune_test_mlp': 'mlp', 'evaluation_cold_fine_tune_test_ncf': 'ncf', 'evaluation_cold_fine_tune_test_cf_embed_all_except_tags_genres': 'cf_with_game_embeddings', 'evaluation_cold_fine_tune_test_gcf_embed_all_except_tags_genres': 'non_linear_cf_with_game_embeddings', 'evaluation_cold_fine_tune_test_mlp_embed_all_except_tags_genres': 'mlp_with_game_embeddings', 'evaluation_cold_fine_tune_test_ncf_embed_all_except_tags_genres': 'ncf_with_game_embeddings'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'user_rank_auc_roc', 'auc_roc', 'mean_positional_error']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='user_rank_auc_roc', ascending=False))
# Out:
#                         evaluation_name  user_rank_auc_roc   auc_roc  \
# 86                     popularity_model           0.660295  0.543463
# 10                     common_neighbors           0.653134  0.810314
# 78              cf_with_game_embeddings           0.631116  0.248812
# 62             mlp_with_game_embeddings           0.592416  0.636390
# 82             ncf_with_game_embeddings           0.569579  0.602841
# 9    non_linear_cf_with_game_embeddings           0.519939  0.454347
# 7                          random_model           0.507380  0.452077
# 68                        non_linear_cf           0.502784  0.611070
# 100                                 ncf           0.501738  0.677918
# 65                                   cf           0.495543  0.092320
# 74                                  mlp           0.483649  0.450576
#
#      mean_positional_error
# 86               19.448393
# 10               17.848381
# 78               21.713603
# ...

# %%
evaluation_names = {'evaluation_cold_fine_tune_test_cf': 'cf', 'evaluation_cold_fine_tune_test_gcf': 'non_linear_cf', 'evaluation_cold_fine_tune_test_mlp': 'mlp', 'evaluation_cold_fine_tune_test_ncf': 'ncf', 'TEMP_evaluation_cold_fine_tune_test_cf_200ep_1e-2_lr_learn_all_100_users': 'slow_fine_tune_cf', 'TEMP_evaluation_cold_fine_tune_test_gcf_200ep_1e-2_lr_learn_all_100_users': 'slow_fine_tune_non_linear_cf', 'TEMP_evaluation_cold_fine_tune_test_mlp_200ep_1e-2_lr_learn_all_100_users': 'slow_fine_tune_mlp', 'TEMP_evaluation_cold_fine_tune_test_ncf_200ep_1e-2_lr_learn_all_100_users': 'slow_fine_tune_ncf'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'user_rank_auc_roc', 'auc_roc', 'mean_positional_error']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='user_rank_auc_roc', ascending=False))
# Out:
#                   evaluation_name  user_rank_auc_roc   auc_roc  \
# 14             slow_fine_tune_mlp           0.590914  0.724647
# 43             slow_fine_tune_ncf           0.575681  0.697851
# 26   slow_fine_tune_non_linear_cf           0.538638  0.384613
# 67              slow_fine_tune_cf           0.505944  0.353222
# 68                  non_linear_cf           0.502784  0.611070
# 100                           ncf           0.501738  0.677918
# 65                             cf           0.495543  0.092320
# 74                            mlp           0.483649  0.450576
#
#      mean_positional_error
# 14               16.239958
# 43               17.531867
# 26               17.188038
# 67               21.255637
# 68               21.181616
# 100              21.501036
# 65               22.288533
# 74               20.953978

# %%
evaluation_names = {'evaluation_cold_fine_tune_test_random_model_learnable_users': 'random_model', 'evaluation_cold_fine_tune_test_popularity_model_learnable_users': 'popularity_model', 'evaluation_cold_fine_tune_test_common_neighbors_learnable_users': 'common_neighbors', 'evaluation_cold_fine_tune_test_cf_learnable_users': 'cf', 'evaluation_cold_fine_tune_test_gcf_learnable_users': 'non_linear_cf', 'evaluation_cold_fine_tune_test_mlp_learnable_users': 'mlp', 'evaluation_cold_fine_tune_test_ncf_learnable_users': 'ncf', 'evaluation_cold_fine_tune_test_cf_embed_all_except_tags_genres_learnable_users': 'cf_with_game_embeddings', 'evaluation_cold_fine_tune_test_gcf_embed_all_except_tags_genres_learnable_users': 'non_linear_cf_with_game_embeddings', 'evaluation_cold_fine_tune_test_mlp_embed_all_except_tags_genres_learnable_users': 'mlp_with_game_embeddings', 'evaluation_cold_fine_tune_test_ncf_embed_all_except_tags_genres_learnable_users': 'ncf_with_game_embeddings'}
df = results.loc[results['evaluation_name'].isin(evaluation_names), ['evaluation_name', 'user_rank_auc_roc', 'auc_roc', 'mean_positional_error']].copy()
df['evaluation_name'] = df['evaluation_name'].map(evaluation_names)
display(df.sort_values(by='user_rank_auc_roc', ascending=False))
# Out:
#                        evaluation_name  user_rank_auc_roc   auc_roc  \
# 28             cf_with_game_embeddings           0.620536  0.439424
# 27                    popularity_model           0.615208  0.524773
# 25                    common_neighbors           0.610526  0.691885
# 21            ncf_with_game_embeddings           0.560026  0.587125
# 29            mlp_with_game_embeddings           0.542427  0.589454
# 84  non_linear_cf_with_game_embeddings           0.520933  0.585151
# 40                        random_model           0.500619  0.440660
#
#     mean_positional_error
# 28              94.213135
# 27              80.150287
# 25              73.521420
# 21              88.048520
# 29              87.325357
# 84              89.530892
# 40              93.041118
