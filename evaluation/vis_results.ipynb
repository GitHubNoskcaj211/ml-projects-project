# %%
import sys
import os
sys.path.append(os.path.join(os.path.abspath(''), '../'))

from evaluation.evaluation_harness import SAVED_EVALUATION_PATH
import os
import pandas as pd

# %%
def parse_metrics_file(file_path):
    metrics = {}
    with open(file_path, 'r') as file:
        for line in file:
            key, value = line.strip().split(': ')
            metrics[key] = float(value)
    return metrics

subfolders = [f.path for f in os.scandir(SAVED_EVALUATION_PATH) if f.is_dir()]
data = []
for subfolder in subfolders:
    metrics_file_path = os.path.join(subfolder, 'metrics.txt')
    
    if os.path.exists(metrics_file_path):
        metrics_data = parse_metrics_file(metrics_file_path)
        data.append({'evaluation_name': subfolder.split('/')[-1], **metrics_data})

results = pd.DataFrame(data)

# %%
def display_ranked_column(column_name):
    display(results.sort_values(by=column_name, ascending=False)[['evaluation_name', column_name]])

# %%
display_ranked_column('user_rank_auc_roc')
# Out:
#                              evaluation_name  user_rank_auc_roc
# 29            test_mlp_embed_all_except_tags           0.697817
# 3             test_ncf_embed_all_except_tags           0.692021
# 16    test_common_neighbors_constant_scoring           0.668630
# 30  test_common_neighbors_percentile_scoring           0.665718
# 31      cold_fine_tune_test_popularity_model           0.662959
# 33                     test_popularity_model           0.660133
# 22    test_popularity_model_constant_scoring           0.660133
# 15      warm_fine_tune_test_popularity_model           0.659982
# 0                      test_common_neighbors           0.651126
# 36               test_gcf_percentile_scoring           0.644475
# 17                 test_ncf_low_weight_decay           0.639596
# 21                      test_mlp_embed_price           0.638482
# 5              test_cf_embed_all_except_tags           0.637683
# 11                 test_mlp_low_weight_decay           0.622961
# 32                                  test_mlp           0.619454
# 12    test_gcf_low_weight_decay_increased_lr           0.612100
# 19                  test_cf_low_weight_decay           0.611466
# 23    test_ncf_low_weight_decay_increased_lr           0.611387
# 9                        test_cf_embed_price           0.605476
# 7                       test_ncf_embed_price           0.605325
# 26                                  test_ncf           0.596702
# 27                test_cf_percentile_scoring           0.591115
# 35            test_gcf_embed_all_except_tags           0.587086
# 24    test_mlp_low_weight_decay_increased_lr           0.580140
# 28                 test_gcf_low_weight_decay           0.568005
# 13                      test_gcf_embed_price           0.566036
# 2                test_ncf_percentile_scoring           0.556878
# 37                                  test_gcf           0.534685
# 14               test_mlp_percentile_scoring           0.512091
# 20                                   test_cf           0.502220
# 34                  test_cf_constant_scoring           0.502136
# 6                          test_random_model           0.500380
# 10          cold_fine_tune_test_random_model           0.499119
# 25                 test_gcf_constant_scoring           0.499115
# 18          warm_fine_tune_test_random_model           0.497826
# 4         test_random_model_constant_scoring           0.497285
# 1                  test_ncf_constant_scoring           0.495853
# 8                  test_mlp_constant_scoring           0.473305

# %%
display_ranked_column('auc_roc')
# Out:
#                              evaluation_name   auc_roc
# 16    test_common_neighbors_constant_scoring  0.879927
# 30  test_common_neighbors_percentile_scoring  0.878156
# 0                      test_common_neighbors  0.861342
# 12    test_gcf_low_weight_decay_increased_lr  0.785994
# 23    test_ncf_low_weight_decay_increased_lr  0.749603
# 27                test_cf_percentile_scoring  0.744858
# 19                  test_cf_low_weight_decay  0.734021
# 5              test_cf_embed_all_except_tags  0.730409
# 9                        test_cf_embed_price  0.724937
# 35            test_gcf_embed_all_except_tags  0.712664
# 28                 test_gcf_low_weight_decay  0.701625
# 24    test_mlp_low_weight_decay_increased_lr  0.701228
# 13                      test_gcf_embed_price  0.698866
# 17                 test_ncf_low_weight_decay  0.692817
# 3             test_ncf_embed_all_except_tags  0.683187
# 29            test_mlp_embed_all_except_tags  0.671305
# 11                 test_mlp_low_weight_decay  0.668366
# 21                      test_mlp_embed_price  0.663412
# 7                       test_ncf_embed_price  0.658127
# 32                                  test_mlp  0.655537
# 31      cold_fine_tune_test_popularity_model  0.641504
# 26                                  test_ncf  0.625572
# 36               test_gcf_percentile_scoring  0.617008
# 37                                  test_gcf  0.562505
# 33                     test_popularity_model  0.551558
# 22    test_popularity_model_constant_scoring  0.551558
# 15      warm_fine_tune_test_popularity_model  0.551399
# 25                 test_gcf_constant_scoring  0.529370
# 8                  test_mlp_constant_scoring  0.506976
# 2                test_ncf_percentile_scoring  0.499556
# 10          cold_fine_tune_test_random_model  0.487864
# 14               test_mlp_percentile_scoring  0.478127
# 1                  test_ncf_constant_scoring  0.466524
# 34                  test_cf_constant_scoring  0.462377
# 20                                   test_cf  0.462280
# 6                          test_random_model  0.438924
# 18          warm_fine_tune_test_random_model  0.435098
# 4         test_random_model_constant_scoring  0.434990

# %%
display_ranked_column('mean_positional_error')
# Out:
#                              evaluation_name  mean_positional_error
# 10          cold_fine_tune_test_random_model              79.541822
# 31      cold_fine_tune_test_popularity_model              69.485655
# 20                                   test_cf              21.015693
# 18          warm_fine_tune_test_random_model              20.952527
# 6                          test_random_model              20.881921
# 37                                  test_gcf              20.241462
# 22    test_popularity_model_constant_scoring              20.082545
# 16    test_common_neighbors_constant_scoring              20.079159
# 1                  test_ncf_constant_scoring              20.078987
# 34                  test_cf_constant_scoring              20.078981
# 4         test_random_model_constant_scoring              20.078981
# 25                 test_gcf_constant_scoring              20.078980
# 8                  test_mlp_constant_scoring              20.078971
# 35            test_gcf_embed_all_except_tags              18.620077
# 28                 test_gcf_low_weight_decay              18.614020
# 13                      test_gcf_embed_price              18.523962
# 33                     test_popularity_model              18.282347
# 15      warm_fine_tune_test_popularity_model              18.267066
# 32                                  test_mlp              17.949893
# 36               test_gcf_percentile_scoring              17.739832
# 26                                  test_ncf              17.286777
# 0                      test_common_neighbors              17.231736
# 21                      test_mlp_embed_price              16.190981
# 11                 test_mlp_low_weight_decay              16.025783
# 17                 test_ncf_low_weight_decay              15.973809
# 29            test_mlp_embed_all_except_tags              15.949710
# 7                       test_ncf_embed_price              15.794612
# 3             test_ncf_embed_all_except_tags              15.784968
# 30  test_common_neighbors_percentile_scoring              15.380188
# 5              test_cf_embed_all_except_tags              14.521566
# 12    test_gcf_low_weight_decay_increased_lr              14.438438
# 19                  test_cf_low_weight_decay              14.421820
# 9                        test_cf_embed_price              14.394619
# 14               test_mlp_percentile_scoring              12.940456
# 24    test_mlp_low_weight_decay_increased_lr              12.913124
# 2                test_ncf_percentile_scoring              12.859828
# 23    test_ncf_low_weight_decay_increased_lr              12.772967
# 27                test_cf_percentile_scoring              12.644981
