# %%
import sys
import os
sys.path.append(os.path.join(os.path.abspath(''), '../'))

from evaluation.evaluation_harness import SAVED_EVALUATION_PATH
import os
import pandas as pd

# %%
def parse_metrics_file(file_path):
    metrics = {}
    with open(file_path, 'r') as file:
        for line in file:
            key, value = line.strip().split(': ')
            metrics[key] = float(value)
    return metrics

subfolders = [f.path for f in os.scandir(SAVED_EVALUATION_PATH) if f.is_dir()]
data = []
for subfolder in subfolders:
    metrics_file_path = os.path.join(subfolder, 'metrics.txt')
    
    if os.path.exists(metrics_file_path):
        metrics_data = parse_metrics_file(metrics_file_path)
        data.append({'evaluation_name': subfolder.split('/')[-1], **metrics_data})

results = pd.DataFrame(data)

# %%
def display_ranked_column(column_name):
    display(results.sort_values(by=column_name, ascending=False)[['evaluation_name', column_name]])

# %%
display_ranked_column('user_rank_auc_roc')
# Out:
#                                       evaluation_name  user_rank_auc_roc
# 8              test_common_neighbors_constant_scoring           0.668630
# 13           test_common_neighbors_percentile_scoring           0.665718
# 11             test_popularity_model_constant_scoring           0.660133
# 14                              test_popularity_model           0.660133
# 0                               test_common_neighbors           0.651126
# 12   evaluation_test_gcf_embed_all_except_tags_genres           0.641797
# 5     evaluation_test_cf_embed_all_except_tags_genres           0.632482
# 6   evaluation_test_gcf_low_weight_decay_increased_lr           0.616624
# 1    evaluation_test_ncf_embed_all_except_tags_genres           0.615793
# 9   evaluation_test_mlp_low_weight_decay_increased_lr           0.605583
# 10  evaluation_test_ncf_low_weight_decay_increased_lr           0.603030
# 7    evaluation_test_mlp_embed_all_except_tags_genres           0.598630
# 4    evaluation_test_cf_low_weight_decay_increased_lr           0.594917
# 3                                   test_random_model           0.500380
# 2                  test_random_model_constant_scoring           0.497285

# %%
display_ranked_column('auc_roc')
# Out:
#                                       evaluation_name   auc_roc
# 8              test_common_neighbors_constant_scoring  0.879927
# 13           test_common_neighbors_percentile_scoring  0.878156
# 0                               test_common_neighbors  0.861342
# 12   evaluation_test_gcf_embed_all_except_tags_genres  0.793709
# 6   evaluation_test_gcf_low_weight_decay_increased_lr  0.773812
# 7    evaluation_test_mlp_embed_all_except_tags_genres  0.741777
# 1    evaluation_test_ncf_embed_all_except_tags_genres  0.732807
# 4    evaluation_test_cf_low_weight_decay_increased_lr  0.732643
# 10  evaluation_test_ncf_low_weight_decay_increased_lr  0.731144
# 9   evaluation_test_mlp_low_weight_decay_increased_lr  0.729132
# 5     evaluation_test_cf_embed_all_except_tags_genres  0.725672
# 11             test_popularity_model_constant_scoring  0.551558
# 14                              test_popularity_model  0.551558
# 3                                   test_random_model  0.438924
# 2                  test_random_model_constant_scoring  0.434990

# %%
display_ranked_column('mean_positional_error')
# Out:
#                                       evaluation_name  mean_positional_error
# 3                                   test_random_model              20.881921
# 11             test_popularity_model_constant_scoring              20.082545
# 8              test_common_neighbors_constant_scoring              20.079159
# 2                  test_random_model_constant_scoring              20.078981
# 14                              test_popularity_model              18.282347
# 0                               test_common_neighbors              17.231736
# 13           test_common_neighbors_percentile_scoring              15.380188
# 6   evaluation_test_gcf_low_weight_decay_increased_lr              14.723952
# 12   evaluation_test_gcf_embed_all_except_tags_genres              14.341733
# 5     evaluation_test_cf_embed_all_except_tags_genres              14.131554
# 4    evaluation_test_cf_low_weight_decay_increased_lr              13.750220
# 9   evaluation_test_mlp_low_weight_decay_increased_lr              13.033273
# 10  evaluation_test_ncf_low_weight_decay_increased_lr              12.825469
# 1    evaluation_test_ncf_embed_all_except_tags_genres              12.809617
# 7    evaluation_test_mlp_embed_all_except_tags_genres              12.536034
